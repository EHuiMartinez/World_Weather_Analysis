# %%
#import dependencies
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
#Create list for cities
cities = []
#identify nearest city for each latitude and longitude combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add to the cities list.
    if city not in cities:
        cities.append(city)
#Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %%
#import requests library
import requests

#import API key
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc96537f733341bd0fff8330f8c3485f

# %%
#Import datetime module from datetime library
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
 
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": weather_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | butembo
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | bathsheba
# Processing Record 4 of Set 1 | bairiki
# Processing Record 5 of Set 1 | vila franca do campo
# Processing Record 6 of Set 1 | arraial do cabo
# Processing Record 7 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | iwanai
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | tuktoyaktuk
# Processing Record 14 of Set 1 | salalah
# Processing Record 15 of Set 1 | lazaro cardenas
# Processing Record 16 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 1 | saskylakh
# Processing Record 18 of Set 1 | vrakhation
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 1 | port lincoln
# Processing Record 22 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 1 | kavaratti
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | huicungo
# Processing Record 26 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 1 | bardiyah
# Processing Record 28 of Set 1 | kruisfontein
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | newport
# Processing Record 31 of Set 1 | castro
# Processing Record 32 of Set 1 | egvekinot
# Processing Record 33 of Set 1 | cherskiy
# Processing Record 34 of Set 1 | flinders
# Processing Record 35 of Set 1 | sinkat
# City not found. Skipping...
# Processing Record 36 of Set 1 | souillac
# Processing Record 37 of Set 1 | henties bay
# Processing Record 38 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 1 | mbala
# Processing Record 40 of Set 1 | ribeira grande
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | chokurdakh
# Processing Record 43 of Set 1 | upata
# Processing Record 44 of Set 1 | nuuk
# Processing Record 45 of Set 1 | komsomolskiy
# Processing Record 46 of Set 1 | carnarvon
# Processing Record 47 of Set 1 | nanortalik
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | puro
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 1 of Set 2 | cap malheureux
# Processing Record 2 of Set 2 | san quintin
# Processing Record 3 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 2 | carmarthen
# Processing Record 5 of Set 2 | bomet
# Processing Record 6 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | ramnagar
# Processing Record 9 of Set 2 | concepcion del uruguay
# Processing Record 10 of Set 2 | port alfred
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | beloha
# Processing Record 13 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 2 | lavrentiya
# Processing Record 15 of Set 2 | quelimane
# Processing Record 16 of Set 2 | purworejo
# Processing Record 17 of Set 2 | havre-saint-pierre
# Processing Record 18 of Set 2 | brun
# Processing Record 19 of Set 2 | nikolskoye
# Processing Record 20 of Set 2 | khatanga
# Processing Record 21 of Set 2 | mahebourg
# Processing Record 22 of Set 2 | norman wells
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | longyearbyen
# Processing Record 25 of Set 2 | kaitangata
# Processing Record 26 of Set 2 | touros
# Processing Record 27 of Set 2 | makat
# Processing Record 28 of Set 2 | verkhniye sergi
# Processing Record 29 of Set 2 | benjamin constant
# Processing Record 30 of Set 2 | yulara
# Processing Record 31 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | gebre guracha
# Processing Record 34 of Set 2 | ponta do sol
# Processing Record 35 of Set 2 | caxito
# Processing Record 36 of Set 2 | finnsnes
# Processing Record 37 of Set 2 | jamestown
# Processing Record 38 of Set 2 | zhengjiatun
# Processing Record 39 of Set 2 | karonga
# Processing Record 40 of Set 2 | okha
# Processing Record 41 of Set 2 | ushtobe
# Processing Record 42 of Set 2 | port macquarie
# Processing Record 43 of Set 2 | hithadhoo
# Processing Record 44 of Set 2 | dingle
# Processing Record 45 of Set 2 | torbay
# Processing Record 46 of Set 2 | faanui
# Processing Record 47 of Set 2 | walvis bay
# Processing Record 48 of Set 2 | cidreira
# Processing Record 49 of Set 2 | bredasdorp
# Processing Record 50 of Set 2 | barrow
# Processing Record 1 of Set 3 | hofn
# Processing Record 2 of Set 3 | nowa sol
# Processing Record 3 of Set 3 | yar-sale
# Processing Record 4 of Set 3 | saint-philippe
# Processing Record 5 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 3 | sola
# Processing Record 7 of Set 3 | jacareacanga
# Processing Record 8 of Set 3 | atuona
# Processing Record 9 of Set 3 | mar del plata
# Processing Record 10 of Set 3 | ambon
# Processing Record 11 of Set 3 | kodinsk
# Processing Record 12 of Set 3 | north bend
# Processing Record 13 of Set 3 | butaritari
# Processing Record 14 of Set 3 | bitung
# Processing Record 15 of Set 3 | avarua
# Processing Record 16 of Set 3 | nioro
# Processing Record 17 of Set 3 | cabo san lucas
# Processing Record 18 of Set 3 | baruun-urt
# Processing Record 19 of Set 3 | varadero
# Processing Record 20 of Set 3 | hailar
# Processing Record 21 of Set 3 | viedma
# Processing Record 22 of Set 3 | pisco
# Processing Record 23 of Set 3 | qaanaaq
# Processing Record 24 of Set 3 | lugovoy
# Processing Record 25 of Set 3 | hilo
# Processing Record 26 of Set 3 | vestmanna
# Processing Record 27 of Set 3 | kodiak
# Processing Record 28 of Set 3 | sulangan
# Processing Record 29 of Set 3 | gurupi
# Processing Record 30 of Set 3 | inhambane
# Processing Record 31 of Set 3 | ust-maya
# Processing Record 32 of Set 3 | vao
# Processing Record 33 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 3 | lorengau
# Processing Record 35 of Set 3 | noumea
# Processing Record 36 of Set 3 | klaksvik
# Processing Record 37 of Set 3 | port keats
# Processing Record 38 of Set 3 | odweyne
# Processing Record 39 of Set 3 | namatanai
# Processing Record 40 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 3 | borogontsy
# Processing Record 42 of Set 3 | kostomuksha
# Processing Record 43 of Set 3 | pevek
# Processing Record 44 of Set 3 | matara
# Processing Record 45 of Set 3 | zimovniki
# Processing Record 46 of Set 3 | port elizabeth
# Processing Record 47 of Set 3 | ahipara
# Processing Record 48 of Set 3 | vallenar
# Processing Record 49 of Set 3 | kavieng
# Processing Record 50 of Set 3 | santa comba
# Processing Record 1 of Set 4 | lahat
# Processing Record 2 of Set 4 | saint george
# Processing Record 3 of Set 4 | severo-kurilsk
# Processing Record 4 of Set 4 | husavik
# Processing Record 5 of Set 4 | gamba
# Processing Record 6 of Set 4 | bambous virieux
# Processing Record 7 of Set 4 | yellowknife
# Processing Record 8 of Set 4 | ostroleka
# Processing Record 9 of Set 4 | chengde
# Processing Record 10 of Set 4 | iqaluit
# Processing Record 11 of Set 4 | raha
# Processing Record 12 of Set 4 | velika kladusa
# Processing Record 13 of Set 4 | jaguaribe
# Processing Record 14 of Set 4 | caravelas
# Processing Record 15 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 4 | fukue
# Processing Record 17 of Set 4 | talnakh
# Processing Record 18 of Set 4 | san cristobal
# Processing Record 19 of Set 4 | chuy
# Processing Record 20 of Set 4 | kiunga
# Processing Record 21 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 4 | marsabit
# Processing Record 23 of Set 4 | bekeshevskaya
# Processing Record 24 of Set 4 | tasiilaq
# Processing Record 25 of Set 4 | verkhnyaya toyma
# Processing Record 26 of Set 4 | acapulco
# Processing Record 27 of Set 4 | bulgan
# Processing Record 28 of Set 4 | ugoofaaru
# Processing Record 29 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 4 | narsaq
# Processing Record 31 of Set 4 | kahului
# Processing Record 32 of Set 4 | roald
# Processing Record 33 of Set 4 | rudsar
# Processing Record 34 of Set 4 | luderitz
# Processing Record 35 of Set 4 | yaan
# Processing Record 36 of Set 4 | hamilton
# Processing Record 37 of Set 4 | san patricio
# Processing Record 38 of Set 4 | kemijarvi
# Processing Record 39 of Set 4 | pedro carbo
# Processing Record 40 of Set 4 | innisfail
# Processing Record 41 of Set 4 | antalaha
# Processing Record 42 of Set 4 | prosperous
# Processing Record 43 of Set 4 | bethel
# Processing Record 44 of Set 4 | belyy yar
# Processing Record 45 of Set 4 | tazovskiy
# Processing Record 46 of Set 4 | chabahar
# Processing Record 47 of Set 4 | boquete
# Processing Record 48 of Set 4 | chapais
# Processing Record 49 of Set 4 | murupara
# Processing Record 50 of Set 4 | uzhhorod
# Processing Record 1 of Set 5 | oga
# Processing Record 2 of Set 5 | carutapera
# Processing Record 3 of Set 5 | pocone
# Processing Record 4 of Set 5 | turayf
# Processing Record 5 of Set 5 | zyryanka
# Processing Record 6 of Set 5 | faya
# Processing Record 7 of Set 5 | taltal
# Processing Record 8 of Set 5 | lebu
# Processing Record 9 of Set 5 | bengkulu
# Processing Record 10 of Set 5 | grand gaube
# Processing Record 11 of Set 5 | deputatskiy
# Processing Record 12 of Set 5 | road town
# Processing Record 13 of Set 5 | dolores
# Processing Record 14 of Set 5 | sambava
# Processing Record 15 of Set 5 | esperance
# Processing Record 16 of Set 5 | gayny
# Processing Record 17 of Set 5 | westport
# Processing Record 18 of Set 5 | hami
# Processing Record 19 of Set 5 | guozhen
# Processing Record 20 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 5 | tuatapere
# Processing Record 22 of Set 5 | novobirilyussy
# Processing Record 23 of Set 5 | vila velha
# Processing Record 24 of Set 5 | devonport
# Processing Record 25 of Set 5 | garowe
# Processing Record 26 of Set 5 | sitka
# Processing Record 27 of Set 5 | xadani
# City not found. Skipping...
# Processing Record 28 of Set 5 | ust-kut
# Processing Record 29 of Set 5 | hasaki
# Processing Record 30 of Set 5 | port hardy
# Processing Record 31 of Set 5 | esso
# Processing Record 32 of Set 5 | saint-georges
# Processing Record 33 of Set 5 | tuy hoa
# Processing Record 34 of Set 5 | nurota
# Processing Record 35 of Set 5 | te anau
# Processing Record 36 of Set 5 | hermanus
# Processing Record 37 of Set 5 | provideniya
# Processing Record 38 of Set 5 | namibe
# Processing Record 39 of Set 5 | saldanha
# Processing Record 40 of Set 5 | kyren
# Processing Record 41 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 5 | hanmer springs
# Processing Record 43 of Set 5 | half moon bay
# Processing Record 44 of Set 5 | neyshabur
# Processing Record 45 of Set 5 | east london
# Processing Record 46 of Set 5 | quatre cocos
# Processing Record 47 of Set 5 | teknaf
# Processing Record 48 of Set 5 | calvinia
# Processing Record 49 of Set 5 | puerto escondido
# Processing Record 50 of Set 5 | verkhoyansk
# Processing Record 1 of Set 6 | rio grande
# Processing Record 2 of Set 6 | santa ines
# Processing Record 3 of Set 6 | bambanglipuro
# Processing Record 4 of Set 6 | ancud
# Processing Record 5 of Set 6 | galesong
# Processing Record 6 of Set 6 | pilar
# Processing Record 7 of Set 6 | hobyo
# Processing Record 8 of Set 6 | shenjiamen
# Processing Record 9 of Set 6 | ankpa
# Processing Record 10 of Set 6 | clyde river
# Processing Record 11 of Set 6 | acarau
# Processing Record 12 of Set 6 | musoma
# Processing Record 13 of Set 6 | marovoay
# Processing Record 14 of Set 6 | planadas
# Processing Record 15 of Set 6 | cangzhou
# Processing Record 16 of Set 6 | abtenau
# Processing Record 17 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 6 | tigil
# Processing Record 19 of Set 6 | huangnihe
# Processing Record 20 of Set 6 | banda aceh
# Processing Record 21 of Set 6 | makurdi
# Processing Record 22 of Set 6 | moose factory
# Processing Record 23 of Set 6 | maghama
# City not found. Skipping...
# Processing Record 24 of Set 6 | mazamari
# Processing Record 25 of Set 6 | zhigansk
# Processing Record 26 of Set 6 | eresos
# Processing Record 27 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 28 of Set 6 | kjollefjord
# Processing Record 29 of Set 6 | verkhnevilyuysk
# Processing Record 30 of Set 6 | mandalgovi
# Processing Record 31 of Set 6 | smithers
# Processing Record 32 of Set 6 | brazzaville
# Processing Record 33 of Set 6 | sao filipe
# Processing Record 34 of Set 6 | erzincan
# Processing Record 35 of Set 6 | geraldton
# Processing Record 36 of Set 6 | demba
# Processing Record 37 of Set 6 | yefimovskiy
# City not found. Skipping...
# Processing Record 38 of Set 6 | kaduqli
# Processing Record 39 of Set 6 | linhares
# Processing Record 40 of Set 6 | batsfjord
# Processing Record 41 of Set 6 | escanaba
# Processing Record 42 of Set 6 | talaya
# Processing Record 43 of Set 6 | umba
# Processing Record 44 of Set 6 | ahuimanu
# Processing Record 45 of Set 6 | dien bien
# City not found. Skipping...
# Processing Record 46 of Set 6 | asyut
# Processing Record 47 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 6 | chino
# Processing Record 49 of Set 6 | nome
# Processing Record 50 of Set 6 | port blair
# Processing Record 1 of Set 7 | cabinda
# Processing Record 2 of Set 7 | inuvik
# Processing Record 3 of Set 7 | thompson
# Processing Record 4 of Set 7 | udachnyy
# Processing Record 5 of Set 7 | cururupu
# Processing Record 6 of Set 7 | sept-iles
# Processing Record 7 of Set 7 | maracacume
# Processing Record 8 of Set 7 | kumano
# Processing Record 9 of Set 7 | badvel
# Processing Record 10 of Set 7 | guangyuan
# Processing Record 11 of Set 7 | codrington
# Processing Record 12 of Set 7 | karratha
# Processing Record 13 of Set 7 | srednekolymsk
# Processing Record 14 of Set 7 | arman
# Processing Record 15 of Set 7 | muyezerskiy
# Processing Record 16 of Set 7 | bismarck
# Processing Record 17 of Set 7 | gladstone
# Processing Record 18 of Set 7 | kieta
# Processing Record 19 of Set 7 | tabas
# Processing Record 20 of Set 7 | vestmannaeyjar
# Processing Record 21 of Set 7 | sabzevar
# Processing Record 22 of Set 7 | lokosovo
# Processing Record 23 of Set 7 | oksfjord
# Processing Record 24 of Set 7 | lima
# Processing Record 25 of Set 7 | olafsvik
# Processing Record 26 of Set 7 | abha
# Processing Record 27 of Set 7 | airai
# Processing Record 28 of Set 7 | shingu
# Processing Record 29 of Set 7 | sorland
# Processing Record 30 of Set 7 | yerbogachen
# Processing Record 31 of Set 7 | goderich
# Processing Record 32 of Set 7 | lompoc
# Processing Record 33 of Set 7 | bonavista
# Processing Record 34 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 7 | maniitsoq
# Processing Record 36 of Set 7 | camana
# Processing Record 37 of Set 7 | novyy urgal
# Processing Record 38 of Set 7 | nazas
# Processing Record 39 of Set 7 | lyuban
# Processing Record 40 of Set 7 | igarka
# Processing Record 41 of Set 7 | oriximina
# Processing Record 42 of Set 7 | yumen
# Processing Record 43 of Set 7 | brae
# Processing Record 44 of Set 7 | hata
# Processing Record 45 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 46 of Set 7 | magadan
# Processing Record 47 of Set 7 | alofi
# Processing Record 48 of Set 7 | mezen
# Processing Record 49 of Set 7 | bayir
# Processing Record 50 of Set 7 | mayo
# Processing Record 1 of Set 8 | kerteh
# City not found. Skipping...
# Processing Record 2 of Set 8 | huarmey
# Processing Record 3 of Set 8 | korla
# Processing Record 4 of Set 8 | bartica
# Processing Record 5 of Set 8 | bonthe
# Processing Record 6 of Set 8 | mutoko
# Processing Record 7 of Set 8 | masagua
# Processing Record 8 of Set 8 | lethem
# Processing Record 9 of Set 8 | victoria
# Processing Record 10 of Set 8 | bilibino
# Processing Record 11 of Set 8 | conde
# Processing Record 12 of Set 8 | san rafael
# Processing Record 13 of Set 8 | nishihara
# Processing Record 14 of Set 8 | anadyr
# Processing Record 15 of Set 8 | port pirie
# Processing Record 16 of Set 8 | katsuura
# Processing Record 17 of Set 8 | union
# Processing Record 18 of Set 8 | payo
# Processing Record 19 of Set 8 | boa esperanca
# Processing Record 20 of Set 8 | axim
# Processing Record 21 of Set 8 | sioux lookout
# Processing Record 22 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 23 of Set 8 | alice springs
# Processing Record 24 of Set 8 | bandarbeyla
# Processing Record 25 of Set 8 | ocampo
# Processing Record 26 of Set 8 | levelland
# Processing Record 27 of Set 8 | guerrero negro
# Processing Record 28 of Set 8 | witbank
# Processing Record 29 of Set 8 | paragominas
# Processing Record 30 of Set 8 | sur
# Processing Record 31 of Set 8 | rapid valley
# Processing Record 32 of Set 8 | kaeo
# Processing Record 33 of Set 8 | satuk
# Processing Record 34 of Set 8 | haines junction
# Processing Record 35 of Set 8 | mana
# Processing Record 36 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 37 of Set 8 | aklavik
# Processing Record 38 of Set 8 | valledupar
# Processing Record 39 of Set 8 | encs
# Processing Record 40 of Set 8 | cuajinicuilapa
# Processing Record 41 of Set 8 | valle de allende
# Processing Record 42 of Set 8 | porto santo
# Processing Record 43 of Set 8 | ndjole
# Processing Record 44 of Set 8 | fortuna
# Processing Record 45 of Set 8 | grand forks
# Processing Record 46 of Set 8 | weihe
# Processing Record 47 of Set 8 | urusha
# Processing Record 48 of Set 8 | calama
# Processing Record 49 of Set 8 | jalu
# Processing Record 50 of Set 8 | oktyabrskiy
# Processing Record 1 of Set 9 | nantucket
# Processing Record 2 of Set 9 | wanxian
# Processing Record 3 of Set 9 | aykhal
# Processing Record 4 of Set 9 | mezhevoy
# Processing Record 5 of Set 9 | staroshcherbinovskaya
# Processing Record 6 of Set 9 | embu
# Processing Record 7 of Set 9 | lagoa
# Processing Record 8 of Set 9 | hare bay
# Processing Record 9 of Set 9 | salina
# Processing Record 10 of Set 9 | ust-kuyga
# Processing Record 11 of Set 9 | ixtapa
# Processing Record 12 of Set 9 | hornepayne
# Processing Record 13 of Set 9 | sabang
# Processing Record 14 of Set 9 | sobolevo
# Processing Record 15 of Set 9 | kubinka
# Processing Record 16 of Set 9 | nampa
# Processing Record 17 of Set 9 | piacabucu
# Processing Record 18 of Set 9 | izhma
# Processing Record 19 of Set 9 | mogadishu
# Processing Record 20 of Set 9 | komatsu
# Processing Record 21 of Set 9 | larap
# Processing Record 22 of Set 9 | richland
# Processing Record 23 of Set 9 | rewari
# Processing Record 24 of Set 9 | mehamn
# Processing Record 25 of Set 9 | fuerte olimpo
# Processing Record 26 of Set 9 | los alamos
# Processing Record 27 of Set 9 | careiro da varzea
# Processing Record 28 of Set 9 | uruzgan
# Processing Record 29 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 30 of Set 9 | sokol
# Processing Record 31 of Set 9 | ubinskoye
# Processing Record 32 of Set 9 | skowhegan
# Processing Record 33 of Set 9 | upernavik
# Processing Record 34 of Set 9 | tanout
# Processing Record 35 of Set 9 | los llanos de aridane
# Processing Record 36 of Set 9 | zhoucheng
# Processing Record 37 of Set 9 | ust-tsilma
# Processing Record 38 of Set 9 | zinder
# Processing Record 39 of Set 9 | kosh-agach
# Processing Record 40 of Set 9 | batagay-alyta
# Processing Record 41 of Set 9 | kati
# Processing Record 42 of Set 9 | antofagasta
# Processing Record 43 of Set 9 | guelengdeng
# City not found. Skipping...
# Processing Record 44 of Set 9 | turukhansk
# Processing Record 45 of Set 9 | moron
# Processing Record 46 of Set 9 | lazurne
# Processing Record 47 of Set 9 | vagay
# Processing Record 48 of Set 9 | hirara
# Processing Record 49 of Set 9 | mangan
# Processing Record 50 of Set 9 | nadym
# Processing Record 1 of Set 10 | coquimbo
# Processing Record 2 of Set 10 | leningradskiy
# Processing Record 3 of Set 10 | roebourne
# Processing Record 4 of Set 10 | auxerre
# Processing Record 5 of Set 10 | gat
# Processing Record 6 of Set 10 | kathmandu
# Processing Record 7 of Set 10 | halifax
# Processing Record 8 of Set 10 | guilin
# Processing Record 9 of Set 10 | suntar
# Processing Record 10 of Set 10 | west wendover
# Processing Record 11 of Set 10 | edson
# Processing Record 12 of Set 10 | agaro
# Processing Record 13 of Set 10 | khandbari
# Processing Record 14 of Set 10 | barabai
# Processing Record 15 of Set 10 | mount isa
# Processing Record 16 of Set 10 | kalmunai
# Processing Record 17 of Set 10 | ouesso
# Processing Record 18 of Set 10 | maymyo
# Processing Record 19 of Set 10 | saint-pierre
# Processing Record 20 of Set 10 | vostok
# Processing Record 21 of Set 10 | porto novo
# Processing Record 22 of Set 10 | majene
# Processing Record 23 of Set 10 | aksarka
# Processing Record 24 of Set 10 | weston
# Processing Record 25 of Set 10 | coahuayana
# Processing Record 26 of Set 10 | qaqortoq
# Processing Record 27 of Set 10 | tabarqah
# City not found. Skipping...
# Processing Record 28 of Set 10 | olinda
# Processing Record 29 of Set 10 | saint-francois
# Processing Record 30 of Set 10 | tilichiki
# Processing Record 31 of Set 10 | baniachang
# Processing Record 32 of Set 10 | san javier
# Processing Record 33 of Set 10 | marzuq
# Processing Record 34 of Set 10 | eureka
# Processing Record 35 of Set 10 | huambo
# Processing Record 36 of Set 10 | san vicente
# Processing Record 37 of Set 10 | sisimiut
# Processing Record 38 of Set 10 | ostrovnoy
# Processing Record 39 of Set 10 | dunedin
# Processing Record 40 of Set 10 | bongandanga
# Processing Record 41 of Set 10 | stepnyak
# Processing Record 42 of Set 10 | juba
# Processing Record 43 of Set 10 | vengerovo
# Processing Record 44 of Set 10 | morros
# Processing Record 45 of Set 10 | hualmay
# Processing Record 46 of Set 10 | ust-kishert
# Processing Record 47 of Set 10 | kloulklubed
# Processing Record 48 of Set 10 | port hedland
# Processing Record 49 of Set 10 | nicoya
# Processing Record 50 of Set 10 | ornskoldsvik
# Processing Record 1 of Set 11 | mackay
# Processing Record 2 of Set 11 | prado
# Processing Record 3 of Set 11 | beringovskiy
# Processing Record 4 of Set 11 | vastervik
# City not found. Skipping...
# Processing Record 5 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 11 | villazon
# Processing Record 7 of Set 11 | tula
# Processing Record 8 of Set 11 | grakhovo
# Processing Record 9 of Set 11 | brainerd
# Processing Record 10 of Set 11 | puerto madero
# Processing Record 11 of Set 11 | hambantota
# Processing Record 12 of Set 11 | labuhan
# Processing Record 13 of Set 11 | porto belo
# Processing Record 14 of Set 11 | angoram
# Processing Record 15 of Set 11 | shimoda
# Processing Record 16 of Set 11 | poronaysk
# Processing Record 17 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 18 of Set 11 | kamaishi
# Processing Record 19 of Set 11 | cayenne
# Processing Record 20 of Set 11 | zhigalovo
# Processing Record 21 of Set 11 | ambilobe
# Processing Record 22 of Set 11 | abu dhabi
# Processing Record 23 of Set 11 | meulaboh
# Processing Record 24 of Set 11 | itoman
# Processing Record 25 of Set 11 | ilulissat
# Processing Record 26 of Set 11 | mkushi
# Processing Record 27 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 28 of Set 11 | constitucion
# Processing Record 29 of Set 11 | salamanca
# Processing Record 30 of Set 11 | khadyzhensk
# Processing Record 31 of Set 11 | resistencia
# Processing Record 32 of Set 11 | karasjok
# Processing Record 33 of Set 11 | bloemfontein
# Processing Record 34 of Set 11 | garden city
# Processing Record 35 of Set 11 | tiksi
# Processing Record 36 of Set 11 | grimari
# City not found. Skipping...
# Processing Record 37 of Set 11 | palana
# Processing Record 38 of Set 11 | sheridan
# Processing Record 39 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 40 of Set 11 | khani
# Processing Record 41 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 42 of Set 11 | aleppo
# Processing Record 43 of Set 11 | tahe
# Processing Record 44 of Set 11 | atlantic city
# Processing Record 45 of Set 11 | lata
# Processing Record 46 of Set 11 | peleduy
# Processing Record 47 of Set 11 | gigmoto
# Processing Record 48 of Set 11 | basco
# Processing Record 49 of Set 11 | gao
# Processing Record 50 of Set 11 | bon accord
# Processing Record 1 of Set 12 | noyabrsk
# Processing Record 2 of Set 12 | oia
# Processing Record 3 of Set 12 | campbellsville
# Processing Record 4 of Set 12 | kaspiysk
# Processing Record 5 of Set 12 | mandera
# Processing Record 6 of Set 12 | orsha
# Processing Record 7 of Set 12 | yingcheng
# Processing Record 8 of Set 12 | carballo
# Processing Record 9 of Set 12 | prince rupert
# Processing Record 10 of Set 12 | razdolnoye
# Processing Record 11 of Set 12 | riyadh
# Processing Record 12 of Set 12 | groningen
# Processing Record 13 of Set 12 | san andres
# Processing Record 14 of Set 12 | la romana
# Processing Record 15 of Set 12 | tutoia
# Processing Record 16 of Set 12 | ostersund
# Processing Record 17 of Set 12 | marmande
# Processing Record 18 of Set 12 | buraydah
# Processing Record 19 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 20 of Set 12 | libertador general san martin
# Processing Record 21 of Set 12 | rawson
# Processing Record 22 of Set 12 | berlevag
# Processing Record 23 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 24 of Set 12 | puerto ayacucho
# Processing Record 25 of Set 12 | ngunguru
# Processing Record 26 of Set 12 | labrea
# Processing Record 27 of Set 12 | nara
# Processing Record 28 of Set 12 | sandy bay
# Processing Record 29 of Set 12 | chernyshevskiy
# Processing Record 30 of Set 12 | sungairaya
# Processing Record 31 of Set 12 | rome
# Processing Record 32 of Set 12 | landerneau
# Processing Record 33 of Set 12 | quang ngai
# Processing Record 34 of Set 12 | kulhudhuffushi
# Processing Record 35 of Set 12 | iskateley
# Processing Record 36 of Set 12 | hasanabad
# Processing Record 37 of Set 12 | adrar
# Processing Record 38 of Set 12 | mareeba
# Processing Record 39 of Set 12 | xuddur
# Processing Record 40 of Set 12 | tacuati
# Processing Record 41 of Set 12 | visby
# Processing Record 42 of Set 12 | mugur-aksy
# Processing Record 43 of Set 12 | miri
# Processing Record 44 of Set 12 | kapit
# Processing Record 45 of Set 12 | praia
# Processing Record 46 of Set 12 | slonim
# Processing Record 47 of Set 12 | nogliki
# Processing Record 48 of Set 12 | liverpool
# Processing Record 49 of Set 12 | whitehorse
# Processing Record 50 of Set 12 | inongo
# Processing Record 1 of Set 13 | brandfort
# Processing Record 2 of Set 13 | rio gallegos
# Processing Record 3 of Set 13 | broome
# Processing Record 4 of Set 13 | margate
# Processing Record 5 of Set 13 | osa
# Processing Record 6 of Set 13 | pangoa
# Processing Record 7 of Set 13 | foki
# Processing Record 8 of Set 13 | phibun mangsahan
# Processing Record 9 of Set 13 | cordeiro
# Processing Record 10 of Set 13 | kambove
# Processing Record 11 of Set 13 | comarapa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the array of dictionaries to a Pandas dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0               Butembo   0.15   29.28     57.79       100         100
# 1               Mataura -46.19  168.86     57.99        62          76
# 2             Bathsheba  13.22  -59.52     77.00        88          75
# 3               Bairiki   1.33  172.98     87.80        62          40
# 4  Vila Franca Do Campo  37.72  -25.43     68.00        88          75
# 5       Arraial Do Cabo -22.97  -42.03     72.07        88           3
# 6                 Vaini -21.20 -175.20     77.00        83          75
# 7                Iwanai  42.97  140.51     54.46        63           3
# 8             Cape Town -33.93   18.42     61.00        93           0
# 9                 Kapaa  22.08 -159.32     71.60        88          90
#
#    Wind Speed Country Current Description                 Date
# 0        2.73      CD          light rain  2020-10-27 02:21:32
# 1        5.99      NZ       broken clouds  2020-10-27 02:20:46
# 2       19.46      BB          light rain  2020-10-27 02:21:07
# 3        5.82      KI    scattered clouds  2020-10-27 02:21:32
# 4       16.11      PT       broken clouds  2020-10-27 02:21:32
# 5       11.25      BR           clear sky  2020-10-27 02:21:32
# 6       10.29      TO       broken clouds  2020-10-27 02:21:32
# 7        3.89      JP           clear sky  2020-10-27 02:21:32
# 8        5.82      ZA           clear sky  2020-10-27 02:20:40
# 9       11.41      US        thunderstorm  2020-10-27 02:21:04

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#                    City Country    Lat     Lng  Max Temp  Humidity  \
# 0               Butembo      CD   0.15   29.28     57.79       100
# 1               Mataura      NZ -46.19  168.86     57.99        62
# 2             Bathsheba      BB  13.22  -59.52     77.00        88
# 3               Bairiki      KI   1.33  172.98     87.80        62
# 4  Vila Franca Do Campo      PT  37.72  -25.43     68.00        88
#
#    Cloudiness  Wind Speed Current Description
# 0         100        2.73          light rain
# 1          76        5.99       broken clouds
# 2          75       19.46          light rain
# 3          40        5.82    scattered clouds
# 4          75       16.11       broken clouds

# %%
#Create the output file(csv)
output_data_file = "WeatherPy_Database.csv"
#Export the city_data into csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
